# %%
transactions = load_csv(RAW_DATA / "08_investor_transactions.csv")

print(transactions.columns.tolist())
print(transactions.dtypes)
print(transactions.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 transactions = load_csv(RAW_DATA / "08_investor_transactions.csv")
#       2
#       3 print(transactions.columns.tolist())
#       4 print(transactions.dtypes)
#
# NameError: name 'load_csv' is not defined
